# %% [markdown]
# <a href="https://colab.research.google.com/github/tron01/DataScienceLAB/blob/main/DataVisualisation_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

tip_df =pd.read_csv("/content/students.csv")
print(tip_df.shape)
# Out:
# (54, 6)

# %%
print(type(tip_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tip_df.head()
# Out:
#             Name  Gender  Attendance  Series1  Series2  FinalMark
# 0   ABHIJITH V A    Male          76     18.8     15.2         60
# 1   ABHISHEK K M    Male          76     15.0     16.4          0
# 2  AISWARYA RAJU  Female          87     16.0     19.6         80
# 3      AJINS U A    Male          83     19.2     13.6         90
# 4     AJOSH JOHN    Male          90     14.6     19.6         80

# %%
tip_df.tail()
# Out:
#                      Name  Gender  Attendance  Series1  Series2  FinalMark
# 49     STAINCY SARA SHAJI  Female          86     16.8     14.8         80
# 50          VARUN VINCENT    Male         100     18.6     19.6        100
# 51         VENKETESH ANIL    Male          92     14.2     13.4         70
# 52     VIJAYALAKSHMI BIJU  Female          97     19.6     18.4         90
# 53  JAYASREE MURALEDHARAN  Female          76     12.8     15.0         79

# %%
tip_df.isnull()
# Out:
#      Name  Gender  Attendance  Series1  Series2  FinalMark
# 0   False   False       False    False    False      False
# 1   False   False       False    False    False      False
# 2   False   False       False    False    False      False
# 3   False   False       False    False    False      False
# 4   False   False       False    False    False      False
# 5   False   False       False    False    False      False
# 6   False   False       False    False    False      False
# 7   False   False       False    False    False      False
# 8   False   False       False    False    False      False
# 9   False   False       False    False    False      False
# 10  False   False       False    False    False      False
# 11  False   False       False    False    False      False
# 12  False   False       False    False    False      False
# 13  False   False       False    False    False      False
# 14  False   False       False    False    False      False
# ...

# %%
tip_df.isnull().sum()
# Out:
# Name          0
# Gender        0
# Attendance    0
# Series1       0
# Series2       0
# FinalMark     0
# dtype: int64

# %%
tip_df['FinalMark']
# Out:
# 0      60
# 1       0
# 2      80
# 3      90
# 4      80
# 5     100
# 6      70
# 7      80
# 8      80
# 9      80
# 10     70
# 11     85
# 12     60
# 13     60
# 14    100
# 15     85
# 16     60
# 17      0
# 18     80
# 19     60
# 20     60
# 21      0
# 22     80
# 23     80
# 24      0
# 25    100
# 26      0
# 27      0
# 28     60
# 29      0
# 30     80
# 31      0
# 32     60
# 33     90
# 34     80
# 35     80
# 36     60
# 37     60
# 38     60
# 39      0
# 40     60
# 41     60
# 42    100
# 43     80
# 44     80
# 45     60
# 46    100
# 47     80
# 48     70
# 49     80
# 50    100
# 51     70
# 52     90
# 53     79
# Name: FinalMark, dtype: int64
